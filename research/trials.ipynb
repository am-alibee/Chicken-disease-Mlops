# %% [markdown]
# ## ConfigBox

# %%
from box import ConfigBox

# %%
import yaml

yaml_file_path = "test.yaml"

# open yaml file & load it's content
with open(yaml_file_path, "r") as yaml_file:
    data = yaml.safe_load(yaml_file)

print(data)
# Out:
# {'name': 'Alibaba', 'age': 10}

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
import os
import gdown

# %%
url = "https://drive.google.com/file/d/1hEIIDJ2ObNRNOlv9J_k2Sdn_9vSUhCs1/view?usp=sharing"
url
# Out:
# 'https://drive.google.com/file/d/1hEIIDJ2ObNRNOlv9J_k2Sdn_9vSUhCs1/view?usp=sharing'

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1hEIIDJ2ObNRNOlv9J_k2Sdn_9vSUhCs1'

# %%
prefix = "https://drive.google.com/uc?export=download&id"
gdown.download(prefix+file_id, "Chicken-Faeces-Image.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id1hEIIDJ2ObNRNOlv9J_k2Sdn_9vSUhCs1
# To: c:\Users\hp\Documents\machine_leanrning\Chicken-disease-Mlops\research\Chicken-Faeces-Image.zip
# 1.70kB [00:00, ?B/s]
# 'Chicken-Faeces-Image.zip'
